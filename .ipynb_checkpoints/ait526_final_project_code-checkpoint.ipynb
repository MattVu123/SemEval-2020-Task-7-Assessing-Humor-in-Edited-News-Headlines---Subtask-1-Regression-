# %% [markdown]
# # SemEval-2020 Task 7: Assessing Humor in Edited News Headlines | Subtask 1: Estimate the funniness of an edited headline on a 0-3 humor scale

# %% [markdown]
# **Team 1:** Matthew Vu, Vu Doan, Prapurna Penmathsa, and Amrisha Dwivedi

# %% [markdown]
# **Description:** The code in this Jupyter Notebook file performs all the necessary operations to accomplish SemEval-2020 Task 7: Assessing Humor in Edited News Headlines | Subtask 1: Estimate the funniness of an edited headline on a 0-3 humor scale.

# %% [markdown]
# **Acknowledgements:** This code is heavily based on the work on the work of Nabil Hossain (https://github.com/n-hossain/semeval-2020-task-7-humicroedit/tree/master) and Salih Tuncer (https://github.com/SalihTuncer/AssessHumor).

# %% [markdown]
# ## Step 0: Import libraries

# %%
import pandas as pd
import numpy as np
import sys
import os
import tensorflow as tf
from transformers import AlbertTokenizer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 5>()
#       3 import sys
#       4 import os
# ----> 5 import tensorflow as tf
#       6 from transformers import AlbertTokenizer
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:41, in <module>
#      38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
# ---> 41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#      42 _os.environ["TF2_BEHAVIOR"] = "1"
#      43 from tensorflow.python import tf2 as _tf2
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\__init__.py:40, in <module>
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      38 # pylint: enable=wildcard-import
#      39
# ---> 40 # from tensorflow.python import keras
#      41 # from tensorflow.python.layers import layers
#      42 from tensorflow.python.saved_model import saved_model
#      43 from tensorflow.python.tpu import api
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\context.py:33, in <module>
#      30 import six
#      32 from tensorflow.core.framework import function_pb2
# ---> 33 from tensorflow.core.protobuf import config_pb2
#      34 from tensorflow.core.protobuf import rewriter_config_pb2
#      35 from tensorflow.python import pywrap_tfe
#
# File ~\anaconda3\lib\site-packages\tensorflow\core\protobuf\config_pb2.py:16, in <module>
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import cost_graph_pb2 as tensorflow_dot_core_dot_framework_dot_cost__graph__pb2
#      17 from tensorflow.core.framework import graph_pb2 as tensorflow_dot_core_dot_framework_dot_graph__pb2
#      18 from tensorflow.core.framework import step_stats_pb2 as tensorflow_dot_core_dot_framework_dot_step__stats__pb2
#
# File ~\anaconda3\lib\site-packages\tensorflow\core\framework\cost_graph_pb2.py:39, in <module>
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/cost_graph.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#      32 _COSTGRAPHDEF_NODE_INPUTINFO = _descriptor.Descriptor(
#      33   name='InputInfo',
#      34   full_name='tensorflow.CostGraphDef.Node.InputInfo',
#      35   filename=None,
#      36   file=DESCRIPTOR,
#      37   containing_type=None,
#      38   fields=[
# ---> 39     _descriptor.FieldDescriptor(
#      40       name='preceding_node', full_name='tensorflow.CostGraphDef.Node.InputInfo.preceding_node', index=0,
#      41       number=1, type=5, cpp_type=1, label=1,
#      42       has_default_value=False, default_value=0,
#      43       message_type=None, enum_type=None, containing_type=None,
#      44       is_extension=False, extension_scope=None,
#      45       serialized_options=None, file=DESCRIPTOR),
#      46     _descriptor.FieldDescriptor(
#      47       name='preceding_port', full_name='tensorflow.CostGraphDef.Node.InputInfo.preceding_port', index=1,
#      48       number=2, type=5, cpp_type=1, label=1,
#      49       has_default_value=False, default_value=0,
#      50       message_type=None, enum_type=None, containing_type=None,
#      51       is_extension=False, extension_scope=None,
#      52       serialized_options=None, file=DESCRIPTOR),
#      53   ],
#      54   extensions=[
#      55   ],
#      56   nested_types=[],
#      57   enum_types=[
#      58   ],
#      59   serialized_options=None,
#      60   is_extendable=False,
#      61   syntax='proto3',
#      62   extension_ranges=[],
#      63   oneofs=[
#      64   ],
#      65   serialized_start=739,
#      66   serialized_end=798,
#      67 )
#      69 _COSTGRAPHDEF_NODE_OUTPUTINFO = _descriptor.Descriptor(
#      70   name='OutputInfo',
#      71   full_name='tensorflow.CostGraphDef.Node.OutputInfo',
#    (...)
#     117   serialized_end=935,
#     118 )
#     120 _COSTGRAPHDEF_NODE = _descriptor.Descriptor(
#     121   name='Node',
#     122   full_name='tensorflow.CostGraphDef.Node',
#    (...)
#     252   serialized_end=935,
#     253 )
#
# File ~\anaconda3\lib\site-packages\google\protobuf\descriptor.py:544, in __new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     540 MAX_LABEL           = 3
#     542 # Must be consistent with C++ constants kMaxNumber, kFirstReservedNumber,
#     543 # and kLastReservedNumber in descriptor.h
# --> 544 MAX_FIELD_NUMBER = (1 << 29) - 1
#     545 FIRST_RESERVED_FIELD_NUMBER = 19000
#     546 LAST_RESERVED_FIELD_NUMBER = 19999
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %% [markdown]
# ## Step 1: Baseline RMSE values

# %% [markdown]
# Recall, we have a validation set called "dev.csv" that is used to develop models, tune hyperparameters, and choose the optimal model out of a series of possible models.  Also, we have a test set called "test.csv" that is used to evaluate the final, best model to get an estimate on how well the chosen model will perform on unseen data in the future.
#
# So, the first step in our analysis is to compute two baseline root mean square error (RMSE) values.  One baseline RMSE value is equal to the validation set's ("dev.csv") RMSE when the predicted funniness score of all edited news headlines in that validation set ("dev.csv") is equal to the average mean funniness score of all edited news headlines in the training set ("train.csv").
#
# The other baseline RMSE value is equal to the test set's ("test.csv") RMSE when the predicted funniness score of all edited news headlines in the test set ("test.csv") is equal to the average mean funniness score of all edited news headlines in the training set ("train.csv").
#
# We want our chosen model to perform better than both the validation and test set baseline RMSE values.

# %%
# this function reads in the training set and the test/validation set 
# and writes an output file that is a copy of the test/validation set
# with the baseline predictions
# inputs:
# train_loc -> directory of the training set
# test_loc -> directory of the test/validation set
# output_name -> name of the desired output file
def baseline_dataset(train_loc, test_loc, output_name):
    # read in the training and test sets
    train = pd.read_csv(train_loc)    
    test = pd.read_csv(test_loc)
    
    # make predictions = average of meanGrade
    pred = np.mean(train['meanGrade'])    
    test['pred'] = pred
    
    # create and write to output file
    output = test[['id','pred']] 
    out_loc = f'datasets/subtask1/baseline/{output_name}'
    output.to_csv(out_loc, index=False)
    
    # show that the output is written
    print(f'{output_name} successfully written.')

# %%
# this function reads in the test/validation set and a dataset containing the baseline 
# predictions to compute the baseline RMSE of that test/validation set
# and returns the baseline RMSE
def baseline_RMSE(truth_loc, prediction_loc):
    # read in the true values
    truth = pd.read_csv(truth_loc, usecols=['id','meanGrade'])
    # read in the baseline predictions
    pred = pd.read_csv(prediction_loc, usecols=['id','pred'])
    
    assert(sorted(truth.id) == sorted(pred.id)),"ID mismatch between ground truth and prediction!"
    
    # compute the baseline RMSE
    data = pd.merge(truth,pred)
    rmse = np.sqrt(np.mean((data['meanGrade'] - data['pred'])**2))
    
    # return baseline RMSE
    return rmse

# %%
# create validation set baseline dataset
baseline_dataset('datasets/subtask1/train.csv', 'datasets/subtask1/dev.csv', 'dev_baseline.csv')
# Out:
# dev_baseline.csv successfully written.

# %%
# compute the output the validation set RMSE value
validation_baseline = baseline_RMSE('datasets/subtask1/dev.csv', 'datasets/subtask1/baseline/dev_baseline.csv')
print(f'Baseline validation set RMSE = {validation_baseline:.3f}')
# Out:
# Baseline validation set RMSE = 0.578

# %%
# create test set baseline dataset
baseline_dataset('datasets/subtask1/train.csv', 'datasets/subtask1/test.csv', 'test_baseline.csv')
# Out:
# test_baseline.csv successfully written.

# %%
# compute the output the test set RMSE value
test_baseline = baseline_RMSE('datasets/subtask1/test.csv', 'datasets/subtask1/baseline/test_baseline.csv')
print(f'Baseline test set RMSE = {test_baseline:.3f}')
# Out:
# Baseline test set RMSE = 0.575

# %% [markdown]
# We want our final model to get a better baseline validation and test set RMSE of 0.578 and 0.575, respectively.

# %%
## Step 2:
